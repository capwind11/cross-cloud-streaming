# %%
from pprint import pprint
import flink_rest_client
from flink_rest_client.v1.client import FlinkRestClientV1

# %%
client: FlinkRestClientV1 = flink_rest_client.FlinkRestClient.get(host="localhost", port=8082)
result = client.overview()

# %%
result
# Out:
# {'taskmanagers': 8,
#  'slots-total': 8,
#  'slots-available': 7,
#  'jobs-running': 1,
#  'jobs-finished': 0,
#  'jobs-cancelled': 14,
#  'jobs-failed': 1,
#  'flink-version': '1.16.1',
#  'flink-commit': 'DeadD0d0'}

# %%
for job in client.jobs.overview():
    if job['state']=='RUNNING':
        pprint(job)
        job_id = job['jid']
# Out:
# {'duration': 308612,
#  'end-time': -1,
#  'jid': '37f70c464fba1f57eeb4fefc10e0e9e6',
#  'last-modification': 1685977994459,
#  'name': 'DownstreamHotPagesExecutor',
#  'start-time': 1685977986746,
#  'state': 'RUNNING',
#  'tasks': {'canceled': 0,
#            'canceling': 0,
#            'created': 0,
#            'deploying': 0,
#            'failed': 0,
#            'finished': 0,
#            'initializing': 0,
#            'reconciling': 0,
#            'running': 10,
#            'scheduled': 0,
#            'total': 10}}

# %%
client.jobs.get(job_id)
# Out:
# {'jid': '37f70c464fba1f57eeb4fefc10e0e9e6',
#  'name': 'DownstreamHotPagesExecutor',
#  'isStoppable': False,
#  'state': 'RUNNING',
#  'start-time': 1685977986746,
#  'end-time': -1,
#  'duration': 312975,
#  'maxParallelism': -1,
#  'now': 1685978299721,
#  'timestamps': {'RUNNING': 1685977986762,
#   'FINISHED': 0,
#   'RECONCILING': 0,
#   'FAILING': 0,
#   'INITIALIZING': 1685977986746,
#   'CANCELED': 0,
#   'SUSPENDED': 0,
#   'RESTARTING': 0,
#   'CREATED': 1685977986756,
#   'FAILED': 0,
#   'CANCELLING': 0},
#  'vertices': [{'id': 'bc764cd8ddf7a0cff126f51c16239658',
#    'name': 'Source: kafka-hotitems',
#    'maxParallelism': 128,
#    'parallelism': 1,
#    'status': 'RUNNING',
#    'start-time': 1685977986865,
#    'end-time': -1,
#    'duration': 312856,
#    'tasks': {'INITIALIZING': 0,
#     'CANCELED': 0,
#     'CANCELING': 0,
#     'FINISHED': 0,
#     'CREATED': 0,
#     'FAILED': 0,
#     'DEPLOYING': 0,
#     'RECONCILING': 0,
#     'RUNNING': 1,
#     'SCHEDULED': 0},
#    'metrics': {'read-bytes': 0,
#     'read-bytes-complete': True,
#     'write-bytes': 17072128,
#     'write-bytes-complete': True,
#     'read-records': 0,
#     'read-records-complete': True,
#     'write-records': 118970,
#     'write-records-complete': True,
#     'accumulated-backpressured-time': 23254,
#     'accumulated-idle-time': 0,
#     'accumulated-busy-time': 'NaN'}},
#   {'id': '0a448493b4782967b150582570326227',
#    'name': 'Map',
#    'maxParallelism': 128,
#    'parallelism': 1,
#    'status': 'RUNNING',
#    'start-time': 1685977986868,
#    'end-time': -1,
#    'duration': 312853,
#    'tasks': {'INITIALIZING': 0,
#     'CANCELED': 0,
#     'CANCELING': 0,
#     'FINISHED': 0,
#     'CREATED': 0,
#     'FAILED': 0,
#     'DEPLOYING': 0,
#     'RECONCILING': 0,
#     'RUNNING': 1,
#     'SCHEDULED': 0},
#    'metrics': {'read-bytes': 16777220,
#     'read-bytes-complete': True,
#     'write-bytes': 15958016,
#     'write-bytes-complete': True,
#     'read-records': 116908,
#     'read-records-complete': True,
#     'write-records': 116908,
#     'write-records-complete': True,
#     'accumulated-backpressured-time': 21075,
#     'accumulated-idle-time': 8923,
#     'accumulated-busy-time': 5902.0}},
#   {'id': 'ea632d67b7d595e5b851708ae9ad79d6',
#    'name': 'Filter',
#    'maxParallelism': 128,
#    'parallelism': 1,
#    'status': 'RUNNING',
#    'start-time': 1685977986869,
#    'end-time': -1,
#    'duration': 312852,
#    'tasks': {'INITIALIZING': 0,
#     'CANCELED': 0,
#     'CANCELING': 0,
#     'FINISHED': 0,
#     'CREATED': 0,
#     'FAILED': 0,
#     'DEPLOYING': 0,
#     'RECONCILING': 0,
#     'RUNNING': 1,
#     'SCHEDULED': 0},
#    'metrics': {'read-bytes': 15695876,
#     'read-bytes-complete': True,
#     'write-bytes': 3899392,
#     'write-bytes-complete': True,
#     'read-records': 114983,
#     'read-records-complete': True,
#     'write-records': 28673,
#     'write-records-complete': True,
#     'accumulated-backpressured-time': 21761,
#     'accumulated-idle-time': 10814,
#     'accumulated-busy-time': 3325.0}},
#   {'id': '6d2677a0ecc3fd8df0b72ec675edf8f4',
#    'name': 'Projection',
#    'maxParallelism': 128,
#    'parallelism': 1,
#    'status': 'RUNNING',
#    'start-time': 1685977986870,
#    'end-time': -1,
#    'duration': 312851,
#    'tasks': {'INITIALIZING': 0,
#     'CANCELED': 0,
#     'CANCELING': 0,
#     'FINISHED': 0,
#     'CREATED': 0,
#     'FAILED': 0,
#     'DEPLOYING': 0,
#     'RECONCILING': 0,
#     'RUNNING': 1,
#     'SCHEDULED': 0},
#    'metrics': {'read-bytes': 3637252,
#     'read-bytes-complete': True,
#     'write-bytes': 1540096,
#     'write-bytes-complete': True,
#     'read-records': 26554,
#     'read-records-complete': True,
#     'write-records': 26554,
#     'write-records-complete': True,
#     'accumulated-backpressured-time': 22859,
#     'accumulated-idle-time': 13318,
#     'accumulated-busy-time': 219.0}},
#   {'id': 'ddb598ad156ed281023ba4eebbe487e3',
#    'name': 'Filter',
#    'maxParallelism': 128,
#    'parallelism': 1,
#    'status': 'RUNNING',
#    'start-time': 1685977986871,
#    'end-time': -1,
#    'duration': 312850,
#    'tasks': {'INITIALIZING': 0,
#     'CANCELED': 0,
#     'CANCELING': 0,
#     'FINISHED': 0,
#     'CREATED': 0,
#     'FAILED': 0,
#     'DEPLOYING': 0,
#     'RECONCILING': 0,
#     'RUNNING': 1,
#     'SCHEDULED': 0},
#    'metrics': {'read-bytes': 1277956,
#     'read-bytes-complete': True,
#     'write-bytes': 1245184,
#     'write-bytes-complete': True,
#     'read-records': 21469,
#     'read-records-complete': True,
#     'write-records': 21469,
#     'write-records-complete': True,
#     'accumulated-backpressured-time': 24101,
#     'accumulated-idle-time': 10754,
#     'accumulated-busy-time': 953.0}},
#   {'id': '46f8730428df9ecd6d7318a02bdc405e',
#    'name': 'Timestamps/Watermarks',
#    'maxParallelism': 128,
#    'parallelism': 1,
#    'status': 'RUNNING',
#    'start-time': 1685977986872,
#    'end-time': -1,
#    'duration': 312849,
#    'tasks': {'INITIALIZING': 0,
#     'CANCELED': 0,
#     'CANCELING': 0,
#     'FINISHED': 0,
#     'CREATED': 0,
#     'FAILED': 0,
#     'DEPLOYING': 0,
#     'RECONCILING': 0,
#     'RUNNING': 1,
#     'SCHEDULED': 0},
#    'metrics': {'read-bytes': 983044,
#     'read-bytes-complete': True,
#     'write-bytes': 983040,
#     'write-bytes-complete': True,
#     'read-records': 16943,
#     'read-records-complete': True,
#     'write-records': 16943,
#     'write-records-complete': True,
#     'accumulated-backpressured-time': 27479,
#     'accumulated-idle-time': 8559,
#     'accumulated-busy-time': 0.0}},
#   {'id': '3e7208d04a005e77687e0b389f9e3814',
#    'name': 'SlidingEventTimeWindows',
#    'maxParallelism': 128,
#    'parallelism': 1,
#    'status': 'RUNNING',
#    'start-time': 1685977986873,
#    'end-time': -1,
#    'duration': 312848,
#    'tasks': {'INITIALIZING': 0,
#     'CANCELED': 0,
#     'CANCELING': 0,
#     'FINISHED': 0,
#     'CREATED': 0,
#     'FAILED': 0,
#     'DEPLOYING': 0,
#     'RECONCILING': 0,
#     'RUNNING': 1,
#     'SCHEDULED': 0},
#    'metrics': {'read-bytes': 720900,
#     'read-bytes-complete': True,
#     'write-bytes': 655360,
#     'write-bytes-complete': True,
#     'read-records': 12051,
#     'read-records-complete': True,
#     'write-records': 4770,
#     'write-records-complete': True,
#     'accumulated-backpressured-time': 0,
#     'accumulated-idle-time': 6972,
#     'accumulated-busy-time': 28729.0}},
#   {'id': '794316e6042dfd2cb159b3f3d374314e',
#    'name': 'Sink: Print to Std. Out',
#    'maxParallelism': 128,
#    'parallelism': 1,
#    'status': 'RUNNING',
#    'start-time': 1685977986874,
#    'end-time': -1,
#    'duration': 312847,
#    'tasks': {'INITIALIZING': 0,
#     'CANCELED': 0,
#     'CANCELING': 0,
#     'FINISHED': 0,
#     'CREATED': 0,
#     'FAILED': 0,
#     'DEPLOYING': 0,
#     'RECONCILING': 0,
#     'RUNNING': 1,
#     'SCHEDULED': 0},
#    'metrics': {'read-bytes': 334177,
#     'read-bytes-complete': True,
#     'write-bytes': 0,
#     'write-bytes-complete': True,
#     'read-records': 4770,
#     'read-records-complete': True,
#     'write-records': 0,
#     'write-records-complete': True,
#     'accumulated-backpressured-time': 0,
#     'accumulated-idle-time': 35416,
#     'accumulated-busy-time': 683.0}},
#   {'id': 'cab122a78246a40d4330824b59cd4ec7',
#    'name': 'KeyedProcess',
#    'maxParallelism': 128,
#    'parallelism': 1,
#    'status': 'RUNNING',
#    'start-time': 1685977986874,
#    'end-time': -1,
#    'duration': 312847,
#    'tasks': {'INITIALIZING': 0,
#     'CANCELED': 0,
#     'CANCELING': 0,
#     'FINISHED': 0,
#     'CREATED': 0,
#     'FAILED': 0,
#     'DEPLOYING': 0,
#     'RECONCILING': 0,
#     'RUNNING': 1,
#     'SCHEDULED': 0},
#    'metrics': {'read-bytes': 334177,
#     'read-bytes-complete': True,
#     'write-bytes': 0,
#     'write-bytes-complete': True,
#     'read-records': 4770,
#     'read-records-complete': True,
#     'write-records': 1,
#     'write-records-complete': True,
#     'accumulated-backpressured-time': 0,
#     'accumulated-idle-time': 37155,
#     'accumulated-busy-time': 0.0}},
#   {'id': 'b57e1aee92d631756543d9aab439856d',
#    'name': 'Sink: Print to Std. Out',
#    'maxParallelism': 128,
#    'parallelism': 1,
#    'status': 'RUNNING',
#    'start-time': 1685977986875,
#    'end-time': -1,
#    'duration': 312846,
#    'tasks': {'INITIALIZING': 0,
#     'CANCELED': 0,
#     'CANCELING': 0,
#     'FINISHED': 0,
#     'CREATED': 0,
#     'FAILED': 0,
#     'DEPLOYING': 0,
#     'RECONCILING': 0,
#     'RUNNING': 1,
#     'SCHEDULED': 0},
#    'metrics': {'read-bytes': 611,
#     'read-bytes-complete': True,
#     'write-bytes': 0,
#     'write-bytes-complete': True,
#     'read-records': 1,
#     'read-records-complete': True,
#     'write-records': 0,
#     'write-records-complete': True,
#     'accumulated-backpressured-time': 0,
#     'accumulated-idle-time': 36968,
#     'accumulated-busy-time': 0.0}}],
#  'status-counts': {'INITIALIZING': 0,
#   'CANCELED': 0,
#   'CANCELING': 0,
#   'FINISHED': 0,
#   'CREATED': 0,
#   'FAILED': 0,
#   'DEPLOYING': 0,
#   'RECONCILING': 0,
#   'RUNNING': 10,
#   'SCHEDULED': 0},
#  'plan': {'jid': '37f70c464fba1f57eeb4fefc10e0e9e6',
#   'name': 'DownstreamHotPagesExecutor',
#   'type': 'STREAMING',
#   'nodes': [{'id': '794316e6042dfd2cb159b3f3d374314e',
#     'parallelism': 1,
#     'operator': '',
#     'operator_strategy': '',
#     'description': 'Sink: Print to Std. Out<br/>',
#     'inputs': [{'num': 0,
#       'id': '3e7208d04a005e77687e0b389f9e3814',
#       'ship_strategy': 'FORWARD',
#       'exchange': 'pipelined_bounded'}],
#     'optimizer_properties': {}},
#    {'id': 'b57e1aee92d631756543d9aab439856d',
#     'parallelism': 1,
#     'operator': '',
#     'operator_strategy': '',
#     'description': 'Sink: Print to Std. Out<br/>',
#     'inputs': [{'num': 0,
#       'id': 'cab122a78246a40d4330824b59cd4ec7',
#       'ship_strategy': 'FORWARD',
#       'exchange': 'pipelined_bounded'}],
#     'optimizer_properties': {}},
#    {'id': 'cab122a78246a40d4330824b59cd4ec7',
#     'parallelism': 1,
#     'operator': '',
#     'operator_strategy': '',
#     'description': 'KeyedProcess<br/>',
#     'inputs': [{'num': 0,
#       'id': '3e7208d04a005e77687e0b389f9e3814',
#       'ship_strategy': 'HASH',
#       'exchange': 'pipelined_bounded'}],
#     'optimizer_properties': {}},
#    {'id': '3e7208d04a005e77687e0b389f9e3814',
#     'parallelism': 1,
#     'operator': '',
#     'operator_strategy': '',
#     'description': 'Window(SlidingEventTimeWindows(600000, 5000), EventTimeTrigger, PageCountAgg, PageCountResult)<br/>',
#     'inputs': [{'num': 0,
#       'id': '46f8730428df9ecd6d7318a02bdc405e',
#       'ship_strategy': 'HASH',
#       'exchange': 'pipelined_bounded'}],
#     'optimizer_properties': {}},
#    {'id': '46f8730428df9ecd6d7318a02bdc405e',
#     'parallelism': 1,
#     'operator': '',
#     'operator_strategy': '',
#     'description': 'Timestamps/Watermarks<br/>',
#     'inputs': [{'num': 0,
#       'id': 'ddb598ad156ed281023ba4eebbe487e3',
#       'ship_strategy': 'FORWARD',
#       'exchange': 'pipelined_bounded'}],
#     'optimizer_properties': {}},
#    {'id': 'ddb598ad156ed281023ba4eebbe487e3',
#     'parallelism': 1,
#     'operator': '',
#     'operator_strategy': '',
#     'description': 'Filter<br/>',
#     'inputs': [{'num': 0,
#       'id': '6d2677a0ecc3fd8df0b72ec675edf8f4',
#       'ship_strategy': 'FORWARD',
#       'exchange': 'pipelined_bounded'}],
#     'optimizer_properties': {}},
#    {'id': '6d2677a0ecc3fd8df0b72ec675edf8f4',
#     'parallelism': 1,
#     'operator': '',
#     'operator_strategy': '',
#     'description': 'Projection<br/>',
#     'inputs': [{'num': 0,
#       'id': 'ea632d67b7d595e5b851708ae9ad79d6',
#       'ship_strategy': 'FORWARD',
#       'exchange': 'pipelined_bounded'}],
#     'optimizer_properties': {}},
#    {'id': 'ea632d67b7d595e5b851708ae9ad79d6',
#     'parallelism': 1,
#     'operator': '',
#     'operator_strategy': '',
#     'description': 'Filter<br/>',
#     'inputs': [{'num': 0,
#       'id': '0a448493b4782967b150582570326227',
#       'ship_strategy': 'FORWARD',
#       'exchange': 'pipelined_bounded'}],
#     'optimizer_properties': {}},
#    {'id': '0a448493b4782967b150582570326227',
#     'parallelism': 1,
#     'operator': '',
#     'operator_strategy': '',
#     'description': 'Map<br/>',
#     'inputs': [{'num': 0,
#       'id': 'bc764cd8ddf7a0cff126f51c16239658',
#       'ship_strategy': 'FORWARD',
#       'exchange': 'pipelined_bounded'}],
#     'optimizer_properties': {}},
#    {'id': 'bc764cd8ddf7a0cff126f51c16239658',
#     'parallelism': 1,
#     'operator': '',
#     'operator_strategy': '',
#     'description': 'Source: kafka-hotitems<br/>',
#     'optimizer_properties': {}}]}}

# %%
# encoding: utf-8
from prometheus_client import Counter, Gauge, Summary
from prometheus_client.core import CollectorRegistry
from prometheus_client.exposition import choose_encoder


class Monitor:
    def __init__(self):
        # 注册收集器&最大耗时map
        self.collector_registry = CollectorRegistry(auto_describe=False)
        self.request_time_max_map = {}

        # 接口调用summary统计
        self.http_request_summary = Summary(name="http_server_requests_seconds",
                                       documentation="Num of request time summary",
                                       labelnames=("method", "code", "uri"),
                                       registry=self.collector_registry)
        # 接口最大耗时统计
        self.http_request_max_cost = Gauge(name="http_server_requests_seconds_max",
                                      documentation="Number of request max cost",
                                      labelnames=("method", "code", "uri"),
                                      registry=self.collector_registry)

        # 请求失败次数统计
        self.http_request_fail_count = Counter(name="http_server_requests_error",
                                          documentation="Times of request fail in total",
                                          labelnames=("method", "code", "uri"),
                                          registry=self.collector_registry)

        # 模型预测耗时统计
        self.http_request_predict_cost = Counter(name="http_server_requests_seconds_predict",
                                            documentation="Seconds of prediction cost in total",
                                            labelnames=("method", "code", "uri"),
                                            registry=self.collector_registry)
        # 图片下载耗时统计
        self.http_request_download_cost = Counter(name="http_server_requests_seconds_download",
                                             documentation="Seconds of download cost in total",
                                             labelnames=("method", "code", "uri"),
                                             registry=self.collector_registry)

    # 获取/metrics结果
    def get_prometheus_metrics_info(self, handler):
        encoder, content_type = choose_encoder(handler.request.headers.get('accept'))
        handler.set_header("Content-Type", content_type)
        handler.write(encoder(self.collector_registry))
        self.reset_request_time_max_map()

    # summary统计
    def set_prometheus_request_summary(self, handler):
        self.http_request_summary.labels(handler.request.method, handler.get_status(), handler.request.path).observe(handler.request.request_time())
        self.set_prometheus_request_max_cost(handler)

    # 自定义summary统计
    def set_prometheus_request_summary_customize(self, method, status, path, cost_time):
        self.http_request_summary.labels(method, status, path).observe(cost_time)
        self.set_prometheus_request_max_cost_customize(method, status, path, cost_time)

    # 失败统计
    def set_prometheus_request_fail_count(self, handler, amount=1.0):
        self.http_request_fail_count.labels(handler.request.method, handler.get_status(), handler.request.path).inc(amount)

    # 自定义失败统计
    def set_prometheus_request_fail_count_customize(self, method, status, path, amount=1.0):
        self.http_request_fail_count.labels(method, status, path).inc(amount)

    # 最大耗时统计
    def set_prometheus_request_max_cost(self, handler):
        requset_cost = handler.request.request_time()
        if self.check_request_time_max_map(handler.request.path, requset_cost):
            self.http_request_max_cost.labels(handler.request.method, handler.get_status(), handler.request.path).set(requset_cost)
            self.request_time_max_map[handler.request.path] = requset_cost

    # 自定义最大耗时统计
    def set_prometheus_request_max_cost_customize(self, method, status, path, cost_time):
        if self.check_request_time_max_map(path, cost_time):
            self.http_request_max_cost.labels(method, status, path).set(cost_time)
            self.request_time_max_map[path] = cost_time

    # 预测耗时统计
    def set_prometheus_request_predict_cost(self, handler, amount=1.0):
        self.http_request_predict_cost.labels(handler.request.method, handler.get_status(), handler.request.path).inc(amount)

    # 自定义预测耗时统计
    def set_prometheus_request_predict_cost_customize(self, method, status, path, cost_time):
        self.http_request_predict_cost.labels(method, status, path).inc(cost_time)

    # 下载耗时统计
    def set_prometheus_request_download_cost(self, handler, amount=1.0):
        self.http_request_download_cost.labels(handler.request.method, handler.get_status(), handler.request.path).inc(amount)

    # 自定义下载耗时统计
    def set_prometheus_request_download_cost_customize(self, method, status, path, cost_time):
        self.http_request_download_cost.labels(method, status, path).inc(cost_time)

    # 校验是否赋值最大耗时map
    def check_request_time_max_map(self, uri, cost):
        if uri not in self.request_time_max_map:
            return True
        if self.request_time_max_map[uri] < cost:
            return True
        return False

    # 重置最大耗时map
    def reset_request_time_max_map(self):
        for key in self.request_time_max_map:
            self.request_time_max_map[key] = 0.0
